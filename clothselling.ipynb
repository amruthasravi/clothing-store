# %%
html_code = """
<!DOCTYPE html>
<html>
<head>
    <title>Online Clothing Store</title>
    <style>
        body { margin: 0; font-family: Arial; background: #f8f8f8; }
        header { background: black; color: white; padding: 20px; text-align: center; }
        nav {
            background: #333;
            padding: 10px;
            text-align: center;
        }
        nav a {
            color: white;
            margin: 15px;
            text-decoration: none;
            font-size: 18px;
        }
        nav a:hover { color: #ffcc00; }

        .products {
            display: flex;
            gap: 20px;
            padding: 30px;
            justify-content: center;
        }
        .item {
            background: white;
            padding: 15px;
            width: 250px;
            border-radius: 10px;
            text-align: center;
            box-shadow: 0px 0px 10px #ddd;
        }
        .item img {
            width: 100%;
            border-radius: 10px;
        }
        .price { font-size: 20px; color: green; margin-top: 10px; }
        button {
            margin-top: 10px;
            padding: 10px;
            background: black;
            color: white;
            border: none;
            border-radius: 5px;
            cursor: pointer;
        }
        button:hover { background: #555; }
    </style>
</head>

<body>

<header>
    <h1>Fashion Hub - Online Clothing Store</h1>
</header>

<nav>
    <a href="#">Home</a>
    <a href="#">Men</a>
    <a href="#">Women</a>
    <a href="#">Kids</a>
    <a href="#">Contact</a>
</nav>

<div class="products">
    <div class="item">
        <img src="https://via.placeholder.com/250x300?text=Men+Tshirt">
        <h3>Men T-Shirt</h3>
        <p class="price">₹499</p>
        <button>Add to Cart</button>
    </div>

    <div class="item">
        <img src="https://via.placeholder.com/250x300?text=Women+Dress">
        <h3>Women Dress</h3>
        <p class="price">₹899</p>
        <button>Add to Cart</button>
    </div>

    <div class="item">
        <img src="https://via.placeholder.com/250x300?text=Kids+Wear">
        <h3>Kids Wear</h3>
        <p class="price">₹399</p>
        <button>Add to Cart</button>
    </div>
</div>

</body>
</html>
"""

with open("index.html", "w") as f:
    f.write(html_code)

"Website page created: index.html"
# Out:
# 'Website page created: index.html'

# %%
from IPython.display import IFrame
IFrame("index.html", width="100%", height=500)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import webbrowser
webbrowser.open("index.html")
# Out:
# (B=(B(BGetting file://localhost/home/60fd1893-57f7-4c45-9bbb-fb572f61538f/index.html(B
#
# >
# True
